#   inflating: ./images/unmasked (1455).jpg
#   inflating: ./images/unmasked (1456).jpg
#   inflating: ./images/unmasked (1457).jpg
#   inflating: ./images/unmasked (1458).jpg
#   inflating: ./images/unmasked (1459).jpg
#   inflating: ./images/unmasked (1460).jpg
#   inflating: ./images/unmasked (1461).jpg
#   inflating: ./images/unmasked (1462).jpg
#   inflating: ./images/unmasked (1463).jpg
#   inflating: ./images/unmasked (1464).jpg
#   inflating: ./images/unmasked (1465).jpg
#   inflating: ./images/unmasked (1466).jpg
#   inflating: ./images/unmasked (1467).jpg
#   inflating: ./images/unmasked (1468).jpg
#   inflating: ./images/unmasked (1469).jpg
#   inflating: ./images/unmasked (1470).jpg
#   inflating: ./images/unmasked (1471).jpg
#   inflating: ./images/unmasked (1472).jpg
#   inflating: ./images/unmasked (1473).jpg
#   inflating: ./images/unmasked (1475).jpg
#   inflating: ./images/unmasked (1476).jpg
#   inflating: ./images/unmasked (1477).jpg
#   inflating: ./images/unmasked (1478).jpg
#   inflating: ./images/unmasked (1479).jpg
#   inflating: ./images/unmasked (1480).jpg
#   inflating: ./images/unmasked (1481).jpg
#   inflating: ./images/unmasked (1482).jpg
#   inflating: ./images/unmasked (1483).jpg
#   inflating: ./images/unmasked (1484).jpg
#   inflating: ./images/unmasked (1485).jpg
#   inflating: ./images/unmasked (1486).jpg
#   inflating: ./images/unmasked (1487).jpg
#   inflating: ./images/unmasked (1488).jpg
#   inflating: ./images/unmasked (1489).jpg
#   inflating: ./images/unmasked (1490).jpg
#   inflating: ./images/unmasked (1491).jpg
#   inflating: ./images/unmasked (1492).jpg
#   inflating: ./images/unmasked (1493).jpg
#   inflating: ./images/unmasked (1494).jpg
#   inflating: ./images/unmasked (1495).jpg
#   inflating: ./images/unmasked (1496).jpg
#   inflating: ./images/unmasked (1497).jpg
#   inflating: ./images/unmasked (1498).jpg
#   inflating: ./images/unmasked (1499).jpg
#   inflating: ./images/unmasked (1500).jpg
# ...
#   inflating: ./annotations/unmasked (1409).xml
#   inflating: ./annotations/unmasked (1410).xml
#   inflating: ./annotations/unmasked (1411).xml
#   inflating: ./annotations/unmasked (1412).xml
#   inflating: ./annotations/unmasked (1413).xml
#   inflating: ./annotations/unmasked (1414).xml
#   inflating: ./annotations/unmasked (1415).xml
#   inflating: ./annotations/unmasked (1416).xml
#   inflating: ./annotations/unmasked (1417).xml
#   inflating: ./annotations/unmasked (1418).xml
#   inflating: ./annotations/unmasked (1419).xml
#   inflating: ./annotations/unmasked (1420).xml
#   inflating: ./annotations/unmasked (1421).xml
#   inflating: ./annotations/unmasked (1422).xml
#   inflating: ./annotations/unmasked (1424).xml
#   inflating: ./annotations/unmasked (1425).xml
#   inflating: ./annotations/unmasked (1426).xml
#   inflating: ./annotations/unmasked (1427).xml
#   inflating: ./annotations/unmasked (1428).xml
#   inflating: ./annotations/unmasked (1429).xml
#   inflating: ./annotations/unmasked (1430).xml
#   inflating: ./annotations/unmasked (1432).xml
#   inflating: ./annotations/unmasked (1433).xml
#   inflating: ./annotations/unmasked (1434).xml
#   inflating: ./annotations/unmasked (1435).xml
#   inflating: ./annotations/unmasked (1436).xml
#   inflating: ./annotations/unmasked (1437).xml
#   inflating: ./annotations/unmasked (1438).xml
#   inflating: ./annotations/unmasked (1439).xml
#   inflating: ./annotations/unmasked (1440).xml
#   inflating: ./annotations/unmasked (1441).xml
#   inflating: ./annotations/unmasked (1442).xml
#   inflating: ./annotations/unmasked (1443).xml
#   inflating: ./annotations/unmasked (1444).xml
#   inflating: ./annotations/unmasked (1445).xml
#   inflating: ./annotations/unmasked (1446).xml
#   inflating: ./annotations/unmasked (1447).xml
#   inflating: ./annotations/unmasked (1448).xml
#   inflating: ./annotations/unmasked (1449).xml
#   inflating: ./annotations/unmasked (1450).xml
#   inflating: ./annotations/unmasked (1451).xml
#   inflating: ./annotations/unmasked (1452).xml
#   inflating: ./annotations/unmasked (1453).xml
#   inflating: ./annotations/unmasked (1454).xml
#   inflating: ./annotations/unmasked (1455).xml
#   inflating: ./annotations/unmasked (1456).xml
#   inflating: ./annotations/unmasked (1457).xml
#   inflating: ./annotations/unmasked (1458).xml
#   inflating: ./annotations/unmasked (1459).xml
#   inflating: ./annotations/unmasked (1460).xml
#   inflating: ./annotations/unmasked (1461).xml
#   inflating: ./annotations/unmasked (1462).xml
#   inflating: ./annotations/unmasked (1463).xml
#   inflating: ./annotations/unmasked (1464).xml
#   inflating: ./annotations/unmasked (1465).xml
#   inflating: ./annotations/unmasked (1466).xml
#   inflating: ./annotations/unmasked (1467).xml
#   inflating: ./annotations/unmasked (1468).xml
#   inflating: ./annotations/unmasked (1469).xml
#   inflating: ./annotations/unmasked (1470).xml
#   inflating: ./annotations/unmasked (1471).xml
#   inflating: ./annotations/unmasked (1472).xml
#   inflating: ./annotations/unmasked (1473).xml
#   inflating: ./annotations/unmasked (1475).xml
#   inflating: ./annotations/unmasked (1476).xml
#   inflating: ./annotations/unmasked (1477).xml
#   inflating: ./annotations/unmasked (1478).xml
#   inflating: ./annotations/unmasked (1479).xml
#   inflating: ./annotations/unmasked (1480).xml
#   inflating: ./annotations/unmasked (1481).xml
#   inflating: ./annotations/unmasked (1482).xml
#   inflating: ./annotations/unmasked (1483).xml
#   inflating: ./annotations/unmasked (1484).xml
#   inflating: ./annotations/unmasked (1485).xml
#   inflating: ./annotations/unmasked (1486).xml
#   inflating: ./annotations/unmasked (1487).xml
#   inflating: ./annotations/unmasked (1488).xml
#   inflating: ./annotations/unmasked (1489).xml
#   inflating: ./annotations/unmasked (1490).xml
#   inflating: ./annotations/unmasked (1491).xml
#   inflating: ./annotations/unmasked (1492).xml
#   inflating: ./annotations/unmasked (1493).xml
#   inflating: ./annotations/unmasked (1494).xml
#   inflating: ./annotations/unmasked (1495).xml
#   inflating: ./annotations/unmasked (1496).xml
#   inflating: ./annotations/unmasked (1497).xml
#   inflating: ./annotations/unmasked (1498).xml
#   inflating: ./annotations/unmasked (1499).xml
#   inflating: ./annotations/unmasked (1500).xml
#   inflating: ./annotations/unmasked (1501).xml
#   inflating: ./annotations/unmasked (1502).xml
#   inflating: ./annotations/unmasked (1503).xml
#   inflating: ./annotations/unmasked (1504).xml
#   inflating: ./annotations/unmasked (1505).xml
#   inflating: ./annotations/unmasked (1506).xml
#   inflating: ./annotations/unmasked (1507).xml
#   inflating: ./annotations/unmasked (1508).xml
#   inflating: ./annotations/unmasked (1509).xml
#   inflating: ./annotations/unmasked (1510).xml
#   inflating: ./annotations/unmasked (1511).xml
#   inflating: ./annotations/unmasked (1512).xml
#   inflating: ./annotations/unmasked (1513).xml
#   inflating: ./annotations/unmasked (1514).xml
#   inflating: ./annotations/unmasked (1515).xml
#   inflating: ./annotations/unmasked (1516).xml
#   inflating: ./annotations/unmasked (1517).xml
#   inflating: ./annotations/unmasked (1518).xml
#   inflating: ./annotations/unmasked (1519).xml
#   inflating: ./annotations/unmasked (1520).xml
#   inflating: ./annotations/unmasked (1521).xml
#   inflating: ./annotations/unmasked (1522).xml
#   inflating: ./annotations/unmasked (1523).xml
#   inflating: ./annotations/unmasked (1524).xml
#   inflating: ./annotations/unmasked (1525).xml
#   inflating: ./annotations/unmasked (1526).xml
#   inflating: ./annotations/unmasked (1527).xml
#   inflating: ./annotations/unmasked (1528).xml
#   inflating: ./annotations/unmasked (1529).xml
#   inflating: ./annotations/unmasked (1530).xml
#   inflating: ./annotations/unmasked (1531).xml
#   inflating: ./annotations/unmasked (1532).xml
#   inflating: ./annotations/unmasked (1533).xml
#   inflating: ./annotations/unmasked (1534).xml
#   inflating: ./annotations/unmasked (1535).xml
#   inflating: ./annotations/unmasked (1536).xml
#   inflating: ./annotations/unmasked (1537).xml
#   inflating: ./annotations/unmasked (1538).xml
#   inflating: ./annotations/unmasked (1539).xml
#   inflating: ./annotations/unmasked (1540).xml
#   inflating: ./annotations/unmasked (1541).xml
#   inflating: ./annotations/unmasked (1542).xml
#   inflating: ./annotations/unmasked (1543).xml
#   inflating: ./annotations/unmasked (1544).xml
#   inflating: ./annotations/unmasked (1545).xml
#   inflating: ./annotations/unmasked (1546).xml
#   inflating: ./annotations/unmasked (1547).xml
#   inflating: ./annotations/unmasked (1549).xml
#   inflating: ./annotations/unmasked (1550).xml
#   inflating: ./annotations/unmasked (1551).xml
#   inflating: ./annotations/unmasked (1552).xml
#   inflating: ./annotations/unmasked (1553).xml
#   inflating: ./annotations/unmasked (1554).xml
#   inflating: ./annotations/unmasked (1555).xml
#   inflating: ./annotations/unmasked (1556).xml
#   inflating: ./annotations/unmasked (1557).xml
#   inflating: ./annotations/unmasked (1558).xml
#   inflating: ./annotations/unmasked (1559).xml
#   inflating: ./annotations/unmasked (1560).xml
#   inflating: ./annotations/unmasked (1561).xml
#   inflating: ./annotations/unmasked (1562).xml
#   inflating: ./annotations/unmasked (1563).xml
#   inflating: ./annotations/unmasked (1564).xml
#   inflating: ./annotations/unmasked (1565).xml
#   inflating: ./annotations/unmasked (1566).xml
#   inflating: ./annotations/unmasked (1567).xml
#   inflating: ./annotations/unmasked (1568).xml
#   inflating: ./annotations/unmasked (1569).xml
#   inflating: ./annotations/unmasked (1570).xml
#   inflating: ./annotations/unmasked (1571).xml
#   inflating: ./annotations/unmasked (1572).xml
#   inflating: ./annotations/unmasked (1573).xml
#   inflating: ./annotations/unmasked (1574).xml
#   inflating: ./annotations/unmasked (1575).xml
#   inflating: ./annotations/unmasked (1576).xml
#   inflating: ./annotations/unmasked (1577).xml
#   inflating: ./annotations/unmasked (1578).xml
#   inflating: ./annotations/unmasked (1579).xml
#   inflating: ./annotations/unmasked (1580).xml
#   inflating: ./annotations/unmasked (1581).xml
#   inflating: ./annotations/unmasked (1582).xml
#   inflating: ./annotations/unmasked (1583).xml
#   inflating: ./annotations/unmasked (1584).xml
#   inflating: ./annotations/unmasked (1585).xml
#   inflating: ./annotations/unmasked (1586).xml
#   inflating: ./annotations/unmasked (1587).xml
#   inflating: ./annotations/unmasked (1588).xml
#   inflating: ./annotations/unmasked (1591).xml
#   inflating: ./annotations/unmasked (1592).xml
#   inflating: ./annotations/unmasked (1593).xml
#   inflating: ./annotations/unmasked (1594).xml
#   inflating: ./annotations/unmasked (1595).xml
#   inflating: ./annotations/unmasked (1596).xml
#   inflating: ./annotations/unmasked (1597).xml
#   inflating: ./annotations/unmasked (1598).xml
#   inflating: ./annotations/unmasked (1599).xml
#   inflating: ./annotations/unmasked (1600).xml
#   inflating: ./annotations/unmasked (1601).xml
#   inflating: ./annotations/unmasked (1602).xml
#   inflating: ./annotations/unmasked (1603).xml
#   inflating: ./annotations/unmasked (1604).xml
#   inflating: ./annotations/unmasked (1605).xml
#   inflating: ./annotations/unmasked (1606).xml
#   inflating: ./annotations/unmasked (1607).xml
#   inflating: ./annotations/unmasked (1609).xml
#   inflating: ./annotations/unmasked (1610).xml
#   inflating: ./annotations/unmasked (1611).xml
#   inflating: ./annotations/unmasked (1612).xml
#   inflating: ./annotations/unmasked (1613).xml
#   inflating: ./annotations/unmasked (1614).xml
#   inflating: ./annotations/unmasked (1615).xml
#   inflating: ./annotations/unmasked (1616).xml
#   inflating: ./annotations/unmasked (1617).xml
#   inflating: ./annotations/unmasked (1618).xml
#   inflating: ./annotations/unmasked (1619).xml
#   inflating: ./annotations/unmasked (1620).xml
#   inflating: ./annotations/unmasked (1621).xml
#   inflating: ./annotations/unmasked (1622).xml
#   inflating: ./annotations/unmasked (1623).xml
#   inflating: ./annotations/unmasked (1624).xml
#   inflating: ./annotations/unmasked (1625).xml
#   inflating: ./annotations/unmasked (1626).xml
#   inflating: ./annotations/unmasked (1627).xml
#   inflating: ./annotations/unmasked (1628).xml
#   inflating: ./annotations/unmasked (1629).xml
#   inflating: ./annotations/unmasked (1630).xml
#   inflating: ./annotations/unmasked (1631).xml
#   inflating: ./annotations/unmasked (1632).xml
#   inflating: ./annotations/unmasked (1633).xml
#   inflating: ./annotations/unmasked (1634).xml
#   inflating: ./annotations/unmasked (1635).xml
#   inflating: ./annotations/unmasked (1636).xml
#   inflating: ./annotations/unmasked (1637).xml
#   inflating: ./annotations/unmasked (1638).xml
#   inflating: ./annotations/unmasked (1639).xml
#   inflating: ./annotations/unmasked (1640).xml
#   inflating: ./annotations/unmasked (1642).xml
#   inflating: ./annotations/unmasked (1644).xml
#   inflating: ./annotations/unmasked (1645).xml
#   inflating: ./annotations/unmasked (1646).xml
#   inflating: ./annotations/unmasked (1647).xml
#   inflating: ./annotations/unmasked (1648).xml
#   inflating: ./annotations/unmasked (1649).xml
#   inflating: ./annotations/unmasked (1650).xml
#   inflating: ./annotations/unmasked (1651).xml
#   inflating: ./annotations/unmasked (1652).xml
#   inflating: ./annotations/unmasked (1653).xml
#   inflating: ./annotations/unmasked (1654).xml
#   inflating: ./annotations/unmasked (1655).xml
#   inflating: ./annotations/unmasked (1656).xml
#   inflating: ./annotations/unmasked (1659).xml
#   inflating: ./annotations/unmasked (1662).xml
#   inflating: ./annotations/unmasked (1663).xml
#   inflating: ./annotations/unmasked (1669).xml
#   inflating: ./annotations/unmasked (1670).xml
#   inflating: ./annotations/unmasked (1671).xml
#   inflating: ./annotations/unmasked (1672).xml
#   inflating: ./annotations/unmasked (1673).xml
#   inflating: ./annotations/unmasked (1674).xml
#   inflating: ./annotations/unmasked (1677).xml
#   inflating: ./annotations/unmasked (1680).xml
#   inflating: ./annotations/unmasked (1682).xml
#   inflating: ./annotations/unmasked (1683).xml
#   inflating: ./annotations/unmasked (1688).xml
#   inflating: ./annotations/unmasked (1690).xml
#   inflating: ./annotations/unmasked (1697).xml
#   inflating: ./annotations/unmasked (1699).xml
#   inflating: ./annotations/unmasked (1708).xml
#   inflating: ./annotations/unmasked (1709).xml
#   inflating: ./annotations/unmasked (1714).xml
#   inflating: ./annotations/unmasked (1716).xml
#   inflating: ./annotations/unmasked (1725).xml
#   inflating: ./annotations/unmasked (1730).xml
#   inflating: ./annotations/unmasked (1732).xml
#   inflating: ./annotations/unmasked (1733).xml
#   inflating: ./annotations/unmasked (1739).xml
#   inflating: ./annotations/unmasked (1741).xml
#   inflating: ./annotations/unmasked (1746).xml
#   inflating: ./annotations/unmasked (1748).xml
#   inflating: ./annotations/unmasked (1752).xml
#   inflating: ./annotations/unmasked (1758).xml
#   inflating: ./annotations/unmasked (1761).xml
#   inflating: ./annotations/unmasked (1762).xml
#   inflating: ./annotations/unmasked (1763).xml
#   inflating: ./annotations/unmasked (1764).xml
#   inflating: ./annotations/unmasked (1769).xml
#   inflating: ./annotations/unmasked (1777).xml
#   inflating: ./annotations/unmasked (1778).xml
#   inflating: ./annotations/unmasked (1785).xml
#   inflating: ./annotations/unmasked (1788).xml
#   inflating: ./annotations/unmasked (1792).xml
#   inflating: ./annotations/unmasked (1793).xml
#   inflating: ./annotations/unmasked (1794).xml
#   inflating: ./annotations/unmasked (1795).xml
#   inflating: ./annotations/unmasked (1796).xml
#   inflating: ./annotations/unmasked (1800).xml
#   inflating: ./annotations/unmasked (1803).xml
#   inflating: ./annotations/unmasked (1807).xml
#   inflating: ./annotations/unmasked (1813).xml
#   inflating: ./annotations/unmasked (1815).xml
#   inflating: ./annotations/unmasked (1819).xml
#   inflating: ./annotations/unmasked (1822).xml
#   inflating: ./annotations/unmasked (1824).xml
#   inflating: ./annotations/unmasked (1827).xml
#   inflating: ./annotations/unmasked (1834).xml
#   inflating: ./annotations/unmasked (1835).xml
#   inflating: ./annotations/unmasked (1839).xml
#   inflating: ./annotations/unmasked (1840).xml
#   inflating: ./annotations/unmasked (1843).xml
#   inflating: ./annotations/unmasked (1852).xml
#   inflating: ./annotations/unmasked (1853).xml
#   inflating: ./annotations/unmasked (1854).xml
#   inflating: ./annotations/unmasked (1856).xml
#   inflating: ./annotations/unmasked (1858).xml
#   inflating: ./annotations/unmasked (1859).xml
#   inflating: ./annotations/unmasked (1864).xml
#   inflating: ./annotations/unmasked (1865).xml
#   inflating: ./annotations/unmasked (1866).xml
#   inflating: ./annotations/unmasked (1867).xml
#   inflating: ./annotations/unmasked (1869).xml
#   inflating: ./annotations/unmasked (1872).xml
#   inflating: ./annotations/unmasked (1875).xml
#   inflating: ./annotations/unmasked (1876).xml
#   inflating: ./annotations/unmasked (1879).xml
#   inflating: ./annotations/unmasked (1882).xml
#   inflating: ./annotations/unmasked (1885).xml
#   inflating: ./annotations/unmasked (1886).xml
#   inflating: ./annotations/unmasked (1888).xml
#   inflating: ./annotations/unmasked (1891).xml
#   inflating: ./annotations/unmasked (1894).xml
#   inflating: ./annotations/unmasked (1897).xml
#   inflating: ./annotations/unmasked (1899).xml
#   inflating: ./annotations/unmasked (1900).xml
#   inflating: ./annotations/unmasked (1903).xml
#   inflating: ./annotations/unmasked (1904).xml
#   inflating: ./annotations/unmasked (1907).xml
#   inflating: ./annotations/unmasked (1912).xml

# %% [markdown]
# # Create test_labels & train_labels
# Divide annotations into test_labels(20%) and train_labels(80%).

# %%
#creating two dir for training and testing
# !mkdir test_labels train_labels

# lists the files inside 'annotations' in a random order (not really random, by their hash value instead)
# Moves the first 274/1370 labels (20% of the labels) to the testing dir: `test_labels`
# !ls annotations/* | sort -R | head -274 | xargs -I{} mv {} test_labels/

# Moves the rest of the labels ( 1096 labels ) to the training dir: `train_labels`
# !ls annotations/* | xargs -I{} mv {} train_labels/

# %%
# !ls
# Out:
# annotations  images  test_labels  train_labels

# %% [markdown]
# # Create the CSV files and the "label_map.pbtxt"
# Current working directory is /mydrive/customTF2/data/
#
# Run xml_to_csv script below to create ***test_labels.csv*** and ***train_labels.csv***
#
# This also creates the ***label_map.pbtxt*** file using the classes mentioned in the xml files.

# %%
#adjusted from: https://github.com/datitran/raccoon_dataset
def xml_to_csv(path):
  classes_names = []
  xml_list = []

  for xml_file in glob.glob(path + '/*.xml'):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
      classes_names.append(member[0].text)
      value = (root.find('filename').text  ,   
               int(root.find('size')[0].text),
               int(root.find('size')[1].text),
               member[0].text,
               int(member[4][0].text),
               int(member[4][1].text),
               int(member[4][2].text),
               int(member[4][3].text))
      xml_list.append(value)
  column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
  xml_df = pd.DataFrame(xml_list, columns=column_name) 
  classes_names = list(set(classes_names))
  classes_names.sort()
  return xml_df, classes_names

for label_path in ['train_labels', 'test_labels']:
  image_path = os.path.join(os.getcwd(), label_path)
  xml_df, classes = xml_to_csv(label_path)
  xml_df.to_csv(f'{label_path}.csv', index=None)
  print(f'Successfully converted {label_path} xml to csv.')

label_map_path = os.path.join("label_map.pbtxt")
pbtxt_content = ""

for i, class_name in enumerate(classes):
    pbtxt_content = (
        pbtxt_content
        + "item {{\n    id: {0}\n    name: '{1}'\n}}\n\n".format(i + 1, class_name)
    )
pbtxt_content = pbtxt_content.strip()
with open(label_map_path, "w") as f:
    f.write(pbtxt_content)
    print('Successfully created label_map.pbtxt ')
# Out:
# Successfully converted train_labels xml to csv.
# Successfully converted test_labels xml to csv.
# Successfully created label_map.pbtxt

# %% [markdown]
# # Create train.record & test.record files
#
# Current working directory is /mydrive/customTF2/data/
#
# Run the *generate_tfrecord.py* script to create *train.record* and *test.record* files

# %%
#Usage:  
#!python generate_tfrecord.py output.csv output_pb.txt /path/to/images output.tfrecords

#For train.record
# !python /content/gdrive/MyDrive/customTF2/generate_tfrecord.py train_labels.csv  label_map.pbtxt images/ train.record

#For test.record
# !python /content/gdrive/MyDrive/customTF2/generate_tfrecord.py test_labels.csv  label_map.pbtxt images/ test.record
# Out:
# 2022-12-16 12:20:32.089551: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:20:32.089657: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:20:32.089677: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# groups: 100% 1096/1096 [00:02<00:00, 432.32it/s]
# Successfully created the TFRecords: /content/gdrive/MyDrive/customTF2/data/train.record
# 2022-12-16 12:20:37.570301: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:20:37.570402: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:20:37.570423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# groups: 100% 274/274 [00:00<00:00, 505.35it/s]
# Successfully created the TFRecords: /content/gdrive/MyDrive/customTF2/data/test.record

# %% [markdown]
# # Download pre-trained model checkpoint
# Current working directory is /mydrive/customTF2/data/
#
# Download **ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz** into the ***data*** folder & unzip it.
#
# A list of detection checkpoints for tensorflow 2.x can be found [here](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md).

# %%
#Download the pre-trained model ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz into the data folder & unzip it.

# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# !tar -xzvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2022-12-16 12:23:18--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 173.194.202.128, 2607:f8b0:400e:c00::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|173.194.202.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M   100MB/s    in 0.2s
#
# 2022-12-16 12:23:18 (100 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # Get the model pipeline config file, make changes to it and put it inside the *data* folder
#
# Current working directory is /mydrive/customTF2/data/
#
# Download **ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config** from ***/content/models/research/object_detection/configs/tf2***. Make the required changes to it and upload it to the ***/mydrive/custom/data*** folder.
#
# **OR**
#
# Edit the config file from ***/content/models/research/object_detection/configs/tf2*** in colab and copy the edited config file to the ***/mydrive/customTF2/data*** folder.
#
# You can also find the pipeline config file inside the model checkpoint folder we just downloaded in the previous step.
#
# **You need to make the following changes:**
# *   change ***num_classes*** to number of your classes.
# *   change ***test.record*** path, ***train.record*** path & ***labelmap*** path to the paths where you have created these files (paths should be relative to your current working directory while training).
# * change ***fine_tune_checkpoint*** to the path of the directory where the downloaded checkpoint from step 12 is.
# * change ***fine_tune_checkpoint_type*** with value **classification** or **detection** depending on the type..
# * change ***batch_size*** to any multiple of 8 depending upon the capability of your GPU.
# (eg:- 24,128,...,512).Mine is set to 64.
# * change ***num_steps*** to number of steps you want the detector to train.

# %%
#copy the edited config file from the configs/tf2 directory to the data/ folder in your drive

# !cp /content/models/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config /content/gdrive/MyDrive/customTF2/data

# %% [markdown]
# # Load Tensorboard

# %%
#load tensorboard

# %load_ext tensorboard
# %tensorboard --logdir '/content/gdrive/MyDrive/customTF2/training'

# %% [markdown]
# # Train the model

# %%
# %cd /content/models/research/object_detection
# Out:
# /content/models/research/object_detection

# %% [markdown]
# # (a) Training using model_main_tf2.py
#
# Here **{PIPELINE_CONFIG_PATH}** points to the pipeline config and **{MODEL_DIR}** points to the directory in which training checkpoints and events will be written.
#
# For best results, you should stop the training when the loss is less than 0.1 if possible, else train the model until the loss does not show any significant change for a while. The ideal loss should be below 0.05 (Try to get the loss as low as possible without overfitting the model. Don’t go too high on training steps to try and lower the loss if the model has already converged viz. if it does not reduce loss significantly any further and takes a while to go down. )

# %%
# Run the command below from the content/models/research/object_detection directory
"""
PIPELINE_CONFIG_PATH=path/to/pipeline.config
MODEL_DIR=path to training checkpoints directory
NUM_TRAIN_STEPS=50000
SAMPLE_1_OF_N_EVAL_EXAMPLES=1

python model_main_tf2.py -- \
  --model_dir=$MODEL_DIR --num_train_steps=$NUM_TRAIN_STEPS \
  --sample_1_of_n_eval_examples=$SAMPLE_1_OF_N_EVAL_EXAMPLES \
  --pipeline_config_path=$PIPELINE_CONFIG_PATH \
  --alsologtostderr
"""

# !python model_main_tf2.py --pipeline_config_path=/content/gdrive/MyDrive/customTF2/data/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config --model_dir=/content/gdrive/MyDrive/customTF2/training --alsologtostderr
# Out:
# 2022-12-16 12:46:53.343062: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:46:53.343215: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:46:53.343237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-16 12:46:56.522842: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1216 12:46:56.538762 139973452085120 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I1216 12:46:56.545713 139973452085120 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1216 12:46:56.545885 139973452085120 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1216 12:46:56.571398 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/gdrive/MyDrive/customTF2/data/train.record']
# I1216 12:46:56.583238 139973452085120 dataset_builder.py:162] Reading unweighted datasets: ['/content/gdrive/MyDrive/customTF2/data/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/gdrive/MyDrive/customTF2/data/train.record']
# I1216 12:46:56.583610 139973452085120 dataset_builder.py:79] Reading record datasets for input file: ['/content/gdrive/MyDrive/customTF2/data/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1216 12:46:56.583727 139973452085120 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1216 12:46:56.583796 139973452085120 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1216 12:46:56.589441 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1216 12:46:56.606292 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1216 12:46:57.153447 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1216 12:47:02.574132 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1216 12:47:05.134016 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1216 12:47:06.563985 139973452085120 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-12-16 12:47:09.375846: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 47775744 exceeds 10% of free system memory.
# 2022-12-16 12:47:10.396595: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 76861224 exceeds 10% of free system memory.
# 2022-12-16 12:47:10.696762: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 26113734 exceeds 10% of free system memory.
# 2022-12-16 12:47:10.842207: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 14929200 exceeds 10% of free system memory.
# 2022-12-16 12:47:10.909729: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 17280000 exceeds 10% of free system memory.
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.568470 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.571126 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.572155 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.573075 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.576330 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.577263 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.578366 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.579364 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.583585 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1216 12:48:12.584514 139973452085120 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1216 12:48:13.826740 139969108612864 deprecation.py:554] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2022-12-16 12:49:55.177318: W tensorflow/tsl/framework/bfc_allocator.cc:360] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# ^C

# %% [markdown]
# ## RETRAINING THE MODEL ( in case you get disconnected )
#
#
# ```
# fine_tune_checkpoint: "/mydrive/customTF2/training/ckpt-X" (where ckpt-X is the latest checkpoint)
#
# ```

# %% [markdown]
# # Test your trained model

# %% [markdown]
# ## Export inference graph
#
# Current working directory is /content/models/research/object_detection

# %%
##Export inference graph
# !python exporter_main_v2.py --trained_checkpoint_dir=/content/gdrive/MyDrive/customTF2/training --pipeline_config_path=/content/gdrive/MyDrive/customTF2/data/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config --output_directory /content/gdrive/MyDrive/customTF2/data/inference_graph
# Out:
# 2022-12-16 12:52:39.791228: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:52:39.792531: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-16 12:52:39.792580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-16 12:52:47.314106: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1216 12:52:47.488258 140328998295424 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1216 12:52:47.554536 140328998295424 deprecation.py:623] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fa0501e26d0>, because it is not built.
# W1216 12:53:05.957961 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fa0501e26d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d565b0>, because it is not built.
# W1216 12:53:06.195718 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d565b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d03df0>, because it is not built.
# W1216 12:53:06.195929 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d03df0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d03eb0>, because it is not built.
# W1216 12:53:06.196034 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d03eb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d09250>, because it is not built.
# W1216 12:53:06.196131 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d09250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d09fd0>, because it is not built.
# W1216 12:53:06.196218 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d09fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d09b80>, because it is not built.
# W1216 12:53:06.196306 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d09b80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d09a30>, because it is not built.
# W1216 12:53:06.196383 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d09a30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d97fa0>, because it is not built.
# W1216 12:53:06.196697 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d97fa0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9de8670>, because it is not built.
# W1216 12:53:06.196801 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9de8670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d4c250>, because it is not built.
# W1216 12:53:06.196892 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f9fe9d4c250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d5f550>, because it is not built.
# W1216 12:53:06.196973 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d5f550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d5f4c0>, because it is not built.
# W1216 12:53:06.197050 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d5f4c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9cfc520>, because it is not built.
# W1216 12:53:06.197140 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9cfc520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9db0d90>, because it is not built.
# W1216 12:53:06.197225 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9db0d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9db00a0>, because it is not built.
# W1216 12:53:06.197300 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9db00a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d70eb0>, because it is not built.
# W1216 12:53:06.197374 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d70eb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d70910>, because it is not built.
# W1216 12:53:06.197456 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d70910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d709d0>, because it is not built.
# W1216 12:53:06.197531 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d709d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d70f40>, because it is not built.
# W1216 12:53:06.197605 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d70f40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d708e0>, because it is not built.
# W1216 12:53:06.197678 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d708e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9cf9640>, because it is not built.
# W1216 12:53:06.197754 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9cf9640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9df3f40>, because it is not built.
# W1216 12:53:06.197828 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9df3f40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9deebe0>, because it is not built.
# W1216 12:53:06.197905 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9deebe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9dee3d0>, because it is not built.
# W1216 12:53:06.197979 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9dee3d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9ecbe80>, because it is not built.
# W1216 12:53:06.198052 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9ecbe80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d82670>, because it is not built.
# W1216 12:53:06.198136 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d82670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9da4d60>, because it is not built.
# W1216 12:53:06.198229 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9da4d60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9da4f10>, because it is not built.
# W1216 12:53:06.198306 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9da4f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9e43310>, because it is not built.
# W1216 12:53:06.198380 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9e43310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9cee850>, because it is not built.
# W1216 12:53:06.198457 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9cee850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d43e20>, because it is not built.
# W1216 12:53:06.198530 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d43e20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d43f70>, because it is not built.
# W1216 12:53:06.198716 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9d43f70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c6b130>, because it is not built.
# W1216 12:53:06.198821 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c6b130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c7d220>, because it is not built.
# W1216 12:53:06.198916 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c7d220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c7d9d0>, because it is not built.
# W1216 12:53:06.199009 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c7d9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c7dbe0>, because it is not built.
# W1216 12:53:06.199123 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c7dbe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d728b0>, because it is not built.
# W1216 12:53:06.199230 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9d728b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0d490>, because it is not built.
# W1216 12:53:06.199325 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0d490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0a400>, because it is not built.
# W1216 12:53:06.199415 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0a400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0a4c0>, because it is not built.
# W1216 12:53:06.199502 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0a4c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0a9d0>, because it is not built.
# W1216 12:53:06.199588 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0a9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0aa90>, because it is not built.
# W1216 12:53:06.199674 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c0aa90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0afa0>, because it is not built.
# W1216 12:53:06.254133 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fe9c0afa0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c224c0>, because it is not built.
# W1216 12:53:06.254289 140328998295424 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9fe9c224c0>, because it is not built.
# W1216 12:53:23.112690 140328998295424 save.py:271] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/customTF2/data/inference_graph/saved_model/assets
# I1216 12:53:28.497062 140328998295424 builder_impl.py:797] Assets written to: /content/gdrive/MyDrive/customTF2/data/inference_graph/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/gdrive/MyDrive/customTF2/data/inference_graph/pipeline.config
# I1216 12:53:29.543679 140328998295424 config_util.py:253] Writing pipeline config file to /content/gdrive/MyDrive/customTF2/data/inference_graph/pipeline.config

# %% [markdown]
# ## Test your trained Object Detection model on images
#
# Current working directory is /content/models/research/object_detection

# %%
# Different font-type for labels text.(This step is optional)
# !wget https://freefontsdownload.net/download/160187/arial.zip
# !unzip arial.zip -d .

# %cd utils/
# !sed -i "s/font = ImageFont.truetype('arial.ttf', 24)/font = ImageFont.truetype('arial.ttf', 50)/" visualization_utils.py
# %cd ..
# Out:
# --2022-12-16 12:54:08--  https://freefontsdownload.net/download/160187/arial.zip
# Resolving freefontsdownload.net (freefontsdownload.net)... 104.21.75.182, 172.67.180.27, 2606:4700:3037::ac43:b41b, ...
# Connecting to freefontsdownload.net (freefontsdownload.net)|104.21.75.182|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172821 (169K) [application/force-download]
# Saving to: ‘arial.zip’
#
# arial.zip           100%[===================>] 168.77K  --.-KB/s    in 0.09s
#
# 2022-12-16 12:54:09 (1.83 MB/s) - ‘arial.zip’ saved [172821/172821]
#
# Archive:  arial.zip
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @#################################@
# @#        Downloaded from        #@
# @#                               #@
# @#   www.FreeFontsDownload.net   #@
# @#                               #@
# @# ---------- More site -------- #@
# @#      https://funnytv.net      #@
# @#                               #@
# @#                               #@
# @#################################@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#   inflating: ./www.freefontsdownload.net.url
#  extracting: ./arial.png
#   inflating: ./arial.ttf
#   inflating: ./freefontsdownload.txt
# /content/models/research/object_detection/utils
# /content/models/research/object_detection

# %%
#Loading the saved_model
import tensorflow as tf
import time
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from PIL import Image
from google.colab.patches import cv2_imshow
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

IMAGE_SIZE = (12, 8) # Output display size as you want
import matplotlib.pyplot as plt
PATH_TO_SAVED_MODEL="/content/gdrive/MyDrive/customTF2/data/inference_graph/saved_model"
print('Loading model...', end='')

# Load saved model and build the detection function
detect_fn=tf.saved_model.load(PATH_TO_SAVED_MODEL)
print('Done!')

#Loading the label_map
category_index=label_map_util.create_category_index_from_labelmap("/content/gdrive/MyDrive/customTF2/data/label_map.pbtxt",use_display_name=True)
#category_index=label_map_util.create_category_index_from_labelmap([path_to_label_map],use_display_name=True)

def load_image_into_numpy_array(path):

    return np.array(Image.open(path))

image_path = "/content/gdrive/MyDrive/mask_test_images/image1.jpg"
#print('Running inference for {}... '.format(image_path), end='')

image_np = load_image_into_numpy_array(image_path)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image_np)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=.4, # Adjust this value to set the minimum probability boxes to be classified as True
      agnostic_mode=False)
# %matplotlib inline
plt.figure(figsize=IMAGE_SIZE, dpi=200)
plt.axis("off")
plt.imshow(image_np_with_detections)
plt.show()
# Out:
# Loading model...Done!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-b568c4f8d398> in <module>
#      30 #print('Running inference for {}... '.format(image_path), end='')
#      31
# ---> 32 image_np = load_image_into_numpy_array(image_path)
#      33
#      34 # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
#
# <ipython-input-33-b568c4f8d398> in load_image_into_numpy_array(path)
#      25 def load_image_into_numpy_array(path):
#      26
# ---> 27     return np.array(Image.open(path))
#      28
#      29 image_path = "/content/gdrive/MyDrive/mask_test_images/image1.jpg"
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/mask_test_images/image1.jpg'
